# %%
import pandas as pd
import numpy as np

# %% [markdown]
# creating a dataframe

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df=pd.DataFrame(data)

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2=pd.DataFrame(data_list)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
cols=['Name','Age','City','Salary']
df3=pd.DataFrame(data_list,columns=cols)
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and indexing

# %%
df3['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df3[['Name','City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# Creating new cols

# %%
df3['Designation']=['Doctor','Eng.','Lawyer','Police']

# %%
df3
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Lawyer
# 3  Linda   42    London   85000      Police

# %%
df3.drop('Designation',axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Lawyer
# 3  Linda   42    London   85000      Police

# %%
df3=df3.drop('Designation',axis=1)

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3.drop('City',axis=1,inplace=True)

# %%
df3
# Out:
#     Name  Age  Salary
# 0   John   28   65000
# 1   Anna   34   70000
# 2  Peter   29   62000
# 3  Linda   42   85000

# %% [markdown]
# rows selection

# %%
df3.loc[0]
# Out:
# Name       John
# Age          28
# Salary    65000
# Name: 0, dtype: object

# %%
df3.loc[[0,1]]
# Out:
#    Name  Age  Salary
# 0  John   28   65000
# 1  Anna   34   70000

# %%
df.iloc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %% [markdown]
# Selecting subsets of rows and cols

# %%
df3
# Out:
#     Name  Age  Salary
# 0   John   28   65000
# 1   Anna   34   70000
# 2  Peter   29   62000
# 3  Linda   42   85000

# %%
df3.loc[[0,1]][['Name','Salary']]
# Out:
#    Name  Salary
# 0  John   65000
# 1  Anna   70000

# %% [markdown]
# Conditional selection

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
cols=['Name','Age','City','Salary']
df2=pd.DataFrame(data_list,columns=cols)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#details of people above 30
df2[df2['Age']>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#above 30 and from paris
df2[(df2['Age']>30) & (df2['City']=='Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
